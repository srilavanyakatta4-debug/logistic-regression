# %%
STEP 11: README.md Create Cheyyi
README.md file create chesi ee matter paste cheyyi.
Markdown
# Logistic Regression Classification

## Objective
Build a binary classifier using Logistic Regression.

## Tools Used
- Python
- Pandas
- Scikit-learn
- Matplotlib

## Dataset
Breast Cancer Wisconsin Dataset

## Steps Performed
1. Loaded dataset
2. Split train and test data
3. Standardized features
4. Trained Logistic Regression model
5. Evaluated using:
   - Confusion Matrix
   - Precision
   - Recall
   - ROC-AUC
6. Plotted ROC Curve

## Output
Model successfully classified binary classes.
1. Difference between Linear and Logistic Regression?
Linear Regression continuous values predict chestundi.
Logistic Regression classification chestundi.
2. What is Sigmoid Function?
Sigmoid function output ni 0 to 1 madhya convert chestundi.
3. Precision vs Recall?
Precision → Correct positive predictions
Recall → Actual positives ni entha identify chesindo
4. What is ROC-AUC?
Model classification performance ni measure chestundi.
5. What is Confusion Matrix?
Prediction results table.
Contains:
TP
TN
FP
FN
6. What happens if classes are imbalanced?
Model majority class ki bias avvachu.
7. How do you choose threshold?
Problem requirement batti threshold select chestham.
8. Can Logistic Regression handle multi-class?
Yes. One-vs-Rest method use chestundi.
Final Files Undali
Plain text
Task4_Logistic_Regression/
│
├── logistic_regression.py
├── README.md
├── screenshots/
│   ├── output.png
│   └── roc_curve.png
